# %%
import pandas as pd
import numpy as np
import re

# %%
# Load the needed datasets
df = pd.read_csv("20180920_sctAnonCopy.csv")
dfCip = pd.read_csv("STVMAJR.csv")

# %%
# Limit displayed rows (change if needed)
pd.options.display.max_rows = 80

# %% [markdown]
# ## A. Basic Data

# %%
# Total number of students
# OPT is tallied elsewhere (from SEVIS at time of fall report)

len(df.index)
# Out:
# 568

# %% [markdown]
# ## B. Academic Level

# %%
# Class sizes

df['Class'].value_counts()
# Out:
# GR - Graduate Student    380
# SO - UG Sophomore         46
# SR - UG Senior            44
# FR - UG Freshman          43
# JR - UG Junior            42
# L1 - Law Year 1            9
# L3 - Law Year 3            3
# L2 - Law Year 2            1
# Name: Class, dtype: int64

# %% [markdown]
# ## C. New/Returning

# %%
# New/returning by level

df.groupby(['Level', 'New/Returning']).size().unstack(fill_value=0).reindex(['Undergraduate','Graduate'], axis=0)
# Out:
# New/Returning  New  Returning
# Level
# Undergraduate   48        127
# Graduate       105        288

# %% [markdown]
# ## D. Enrollment Status

# %%
# Enrollment time by level

df.groupby(['Level', 'Current Time Status']).size().unstack(fill_value=0).reindex(['Undergraduate','Graduate'], axis=0)
# Out:
# Current Time Status  Full-Time  Half-Time  Less than Half-Time  No hours  \
# Level
# Undergraduate              168          2                    0         4
# Graduate                   338         51                    1         1
#
# Current Time Status  Three-Quarter Time "Q"
# Level
# Undergraduate                             1
# Graduate                                  2

# %% [markdown]
# ## E. Visa Type

# %%
# Visa type by level

df.groupby(['Visa Type', 'Level']).size().unstack(fill_value=0).reindex(['Undergraduate','Graduate'], axis=1)
# Out:
# Level      Undergraduate  Graduate
# Visa Type
# E2                     1         0
# F1                   162       329
# F2                     0         1
# FN                     0         1
# FP                     0         3
# H1                     1        31
# H4                     1        18
# HB                     0         2
# J1                     5         5
# JN                     4         0
# L2                     1         1
# TD                     0         1
# U1                     0         1

# %% [markdown]
# ## F. Gender

# %%
# Gender by level

df.groupby(['Level', 'Gender']).size().unstack(fill_value=0).reindex(['Undergraduate','Graduate'], axis=0)
# Out:
# Gender         Female  Male
# Level
# Undergraduate      70   105
# Graduate          195   198

# %% [markdown]
# ## G. Marital Status
#
# We don't report this because it's not in our report.

# %% [markdown]
# ## H. Primary source of funds
#
# We dont report this either, but I singled out our Fulbrights as "International Organization".

# %% [markdown]
# ## I. Field of Study

# %%
# This extracts the 2nd through 5th character in the string, leaving us with the major code
# Don't run this more than once or it will keep cutting off the front character. Restart the kernel if you make any changes. 

df['majr'] = df['majr'].astype(str).str[1:5]
# df['majr'] # uncomment to check

# %%
# This joins the main table to the STVMAJR table and adds a column for their CIP codes. 

mergedDf = df.merge(dfCip, how ='left', on = 'majr')

# %%
# This is your list of cip codes grouped by level

mergedDf.groupby(['cip', 'Level']).size().unstack(fill_value=0).reindex(['Undergraduate','Graduate'], axis=1)
# Out:
# Level     Undergraduate  Graduate
# cip
# 30104.0               3         0
# 90101.0               2         0
# 99999.0               3         0
# 110103.0              0        86
# 110401.0              3         0
# 110701.0             14         0
# 110802.0              0        93
# 130401.0              0        12
# 130406.0              0         3
# 131013.0              0         1
# 131099.0              0         2
# 131202.0              1         4
# 131312.0              0         1
# 139999.0              0         9
# 140801.0              2         0
# 140901.0              5         0
# 141001.0             11        10
# 141901.0             19         8
# 142701.0              0         6
# 143601.0              0         7
# 151501.0              0        12
# 159999.0              0         4
# 220101.0              0        13
# 220201.0              0        20
# 240102.0             11         3
# 260101.0              9         0
# 260202.0              4         0
# 261501.0              1         0
# 270101.0              2         0
# 380101.0              1         0
# 380201.0              0         1
# 390602.0              0         5
# 390604.0              0         1
# 390705.0              0         1
# 400501.0              1         0
# 420101.0              4         0
# 422803.0              0         7
# 440701.0              0         3
# 450601.0              7         0
# 450604.0              1         0
# 450701.0              1         0
# 450901.0              1         0
# 451001.0              2         0
# 451101.0              1         0
# 500901.0              3         0
# 511104.0              1         0
# 512207.0              6         0
# 520201.0              6        25
# 520205.0              6         0
# 520299.0              3         1
# 520301.0              6         0
# 520701.0              4         0
# 520801.0              8         0
# 521001.0              2         0
# 521101.0              4         0
# 521302.0              0        55
# 521304.0              4         0
# 521401.0             12         0
# 540101.0              1         0

# %% [markdown]
# ## J. Place of Origin

# %%
# This is your list of citizenship grouped by level

mergedDf.groupby(['Nation of Citizenship', 'Level']).size().unstack(fill_value=0).reindex(['Undergraduate','Graduate'], axis=1)
# Out:
# Level                           Undergraduate  Graduate
# Nation of Citizenship
# Argentina                                   2         0
# Australia                                   1         0
# Bangladesh                                  0         3
# Bolivia                                     1         0
# Brazil                                      4         7
# Cambodia                                    4         0
# Cameroon                                    0         1
# Canada                                      5         8
# Chile                                       0         2
# China                                      40        81
# Colombia                                    2         2
# Congo, Democratic Rep of the                0         2
# Cote d'Ivoire                               0        12
# Czech Republic                              2         0
# Ecuador                                     1         2
# Egypt                                       2         0
# El Salvador                                 1         1
# Ethiopia                                    2         5
# France                                      1         0
# Germany                                     1         3
# Ghana                                       0         3
# Greece                                      0         1
# Guatemala                                   0         1
# Guinea                                      0         1
# Honduras                                    1         1
# Hong Kong, SpecAdminRegofChina              0         3
# Hungary                                     1         1
# Iceland                                     1         0
# India                                       7        99
# Indonesia                                   2         1
# Ireland                                     0         1
# Italy                                       3         1
# Jamaica                                     2         0
# Japan                                       1         0
# Kazakhstan                                  0         1
# Kenya                                       2         2
# Korea, Republic of                          1         6
# Lebanon                                     0         1
# Madagascar                                  0         1
# Malaysia                                    1         2
# Mauritania                                  0         1
# Mauritius                                   0         1
# Mexico                                      1         2
# Mongolia                                    1         1
# Nepal                                       0        16
# Netherlands                                 1         0
# Nigeria                                     1        10
# Norway                                     13         1
# Pakistan                                    2         4
# Palestinian,Territory Occupied              0         1
# Peru                                        2         8
# Poland                                      0         1
# Rwanda                                      2         0
# Saudi Arabia                               37        45
# Singapore                                   0         2
# Slovakia                                    0         1
# Spain                                       0         3
# Sri Lanka                                   1         2
# Sudan                                       0         2
# Swaziland                                   0         2
# Taiwan, Republic of China                   2         5
# Tanzania, United Republic of                1         1
# Togo                                        1         0
# Turkey                                      0         1
# Turkmenistan                                0         1
# Uganda                                      2         8
# Ukraine                                     0         2
# United Kingdom                              1         1
# Uruguay                                     1         0
# Viet Nam                                   14        12
# Zimbabwe                                    0         4

# %% [markdown]
# ## K. Fields of Study for Top 25 Places of Origin

# %%
# Here we create a df for each country listed and then concat them into a single frame.

bangladesh = mergedDf[mergedDf['Nation of Citizenship'] == 'Bangladesh']
brazil = mergedDf[mergedDf['Nation of Citizenship'] == 'Brazil']
canada = mergedDf[mergedDf['Nation of Citizenship'] == 'Canada']
china = mergedDf[mergedDf['Nation of Citizenship'] == 'China']
colombia = mergedDf[mergedDf['Nation of Citizenship'] == 'Colombia']
france = mergedDf[mergedDf['Nation of Citizenship'] == 'France']
germany = mergedDf[mergedDf['Nation of Citizenship'] == 'Germany']
india = mergedDf[mergedDf['Nation of Citizenship'] == 'India']
indonesia = mergedDf[mergedDf['Nation of Citizenship'] == 'Indonesia']
iran = mergedDf[mergedDf['Nation of Citizenship'] == 'Iran']
japan = mergedDf[mergedDf['Nation of Citizenship'] == 'Japan']
korea = mergedDf[mergedDf['Nation of Citizenship'] == 'Korea, Republic of']
kuwait = mergedDf[mergedDf['Nation of Citizenship'] == 'Kuwait']
malaysia = mergedDf[mergedDf['Nation of Citizenship'] == 'Malaysia']
mexico = mergedDf[mergedDf['Nation of Citizenship'] == 'Mexico']
nepal = mergedDf[mergedDf['Nation of Citizenship'] == 'Nepal']
nigeria = mergedDf[mergedDf['Nation of Citizenship'] == 'Nigeria']
pakistan = mergedDf[mergedDf['Nation of Citizenship'] == 'Pakistan']
saudi = mergedDf[mergedDf['Nation of Citizenship'] == 'Saudi Arabia']
spain = mergedDf[mergedDf['Nation of Citizenship'] == 'Spain']
taiwan = mergedDf[mergedDf['Nation of Citizenship'] == 'Taiwan, Republic of China']
turkey = mergedDf[mergedDf['Nation of Citizenship'] == 'Turkey']
uk = mergedDf[mergedDf['Nation of Citizenship'] == 'United Kingdom']
venezuela = mergedDf[mergedDf['Nation of Citizenship'] == 'Venezuela']
vietnam = mergedDf[mergedDf['Nation of Citizenship'] == 'Viet Nam']

dfTop25A = pd.concat([bangladesh, brazil, canada, china, colombia, france, germany, india, indonesia, iran, japan, korea])
dfTop25B = pd.concat([kuwait, malaysia, mexico, nepal, nigeria, pakistan, saudi, spain, taiwan, turkey, uk, venezuela, vietnam])

# %%
dfTop25A.groupby(['cip', 'Nation of Citizenship']).size().unstack(fill_value=0)
# Out:
# Nation of Citizenship  Bangladesh  Brazil  Canada  China  Colombia  France  \
# cip
# 30104.0                         0       0       0      0         0       0
# 99999.0                         0       0       0      1         0       0
# 110103.0                        0       0       1     22         0       0
# 110401.0                        0       0       0      1         0       0
# 110701.0                        0       0       0      4         0       0
# 110802.0                        2       1       0     23         1       0
# 130401.0                        0       0       0      0         0       0
# 130406.0                        0       0       0      0         0       0
# 131013.0                        0       0       0      1         0       0
# 131099.0                        0       0       0      1         0       0
# 131202.0                        0       0       0      2         0       0
# 139999.0                        0       0       0      3         0       0
# 140801.0                        0       0       0      0         0       0
# 140901.0                        0       0       0      0         0       0
# 141001.0                        0       0       1      3         0       0
# 141901.0                        0       0       0      5         0       0
# 142701.0                        0       0       1      0         0       0
# 143601.0                        0       1       1      0         0       0
# 151501.0                        0       0       0      0         0       0
# 159999.0                        0       0       0      0         0       0
# 220101.0                        0       2       2      3         1       0
# 220201.0                        0       1       0      4         0       0
# 240102.0                        0       0       1      0         0       1
# 260101.0                        0       0       0      2         1       0
# 270101.0                        0       0       0      2         0       0
# 420101.0                        0       0       0      1         0       0
# 422803.0                        0       0       2      1         0       0
# 440701.0                        0       0       0      0         0       0
# 450601.0                        0       0       0      4         0       0
# 451001.0                        0       0       1      0         0       0
# 500901.0                        0       0       0      2         0       0
# 520201.0                        0       1       0      6         0       0
# 520205.0                        0       1       1      0         0       0
# 520299.0                        0       0       2      0         0       0
# 520301.0                        0       0       0      3         0       0
# 520701.0                        0       1       0      1         1       0
# 520801.0                        0       0       0      4         0       0
# 521001.0                        0       0       0      1         0       0
# 521101.0                        0       2       0      0         0       0
# 521302.0                        1       1       0     17         0       0
# 521401.0                        0       0       0      3         0       0
# 540101.0                        0       0       0      1         0       0
#
# Nation of Citizenship  Germany  India  Indonesia  Japan  Korea, Republic of
# cip
# 30104.0                      0      0          0      0                   1
# 99999.0                      0      1          0      0                   0
# 110103.0                     0     20          0      0                   0
# 110401.0                     0      0          0      0                   0
# 110701.0                     0      2          0      1                   0
# 110802.0                     1     40          0      0                   2
# 130401.0                     0      1          0      0                   0
# 130406.0                     0      1          0      0                   0
# 131013.0                     0      0          0      0                   0
# 131099.0                     0      0          0      0                   0
# 131202.0                     0      0          0      0                   0
# 139999.0                     0      0          0      0                   0
# 140801.0                     0      1          0      0                   0
# 140901.0                     0      1          0      0                   0
# 141001.0                     0      3          0      0                   0
# 141901.0                     0      3          0      0                   0
# 142701.0                     0      1          0      0                   0
# 143601.0                     0      1          0      0                   0
# 151501.0                     0      2          0      0                   0
# 159999.0                     0      1          0      0                   0
# 220101.0                     0      1          0      0                   0
# 220201.0                     0      1          0      0                   0
# 240102.0                     1      0          0      0                   0
# 260101.0                     0      0          0      0                   0
# 270101.0                     0      0          0      0                   0
# 420101.0                     0      0          1      0                   0
# 422803.0                     0      2          0      0                   1
# 440701.0                     0      0          0      0                   1
# 450601.0                     0      0          0      0                   0
# 451001.0                     0      0          0      0                   0
# 500901.0                     0      0          0      0                   0
# 520201.0                     1     15          1      0                   0
# 520205.0                     0      0          0      0                   0
# 520299.0                     0      0          0      0                   0
# 520301.0                     0      0          0      0                   0
# 520701.0                     0      0          0      0                   0
# 520801.0                     0      0          0      0                   0
# 521001.0                     0      0          0      0                   0
# 521101.0                     1      0          0      0                   0
# 521302.0                     0      8          1      0                   2
# 521401.0                     0      1          0      0                   0
# 540101.0                     0      0          0      0                   0

# %%
dfTop25B.groupby(['cip', 'Nation of Citizenship']).size().unstack(fill_value=0)
# Out:
# Nation of Citizenship  Malaysia  Mexico  Nepal  Nigeria  Pakistan  \
# cip
# 90101.0                       0       0      0        0         0
# 99999.0                       0       0      0        0         0
# 110103.0                      0       0      7        4         2
# 110401.0                      0       0      0        1         0
# 110701.0                      0       0      0        0         0
# 110802.0                      0       0      5        2         0
# 130401.0                      0       0      0        1         0
# 130406.0                      0       0      0        0         0
# 131099.0                      0       0      0        0         0
# 131202.0                      0       0      0        1         0
# 131312.0                      1       0      0        0         0
# 139999.0                      1       0      0        1         0
# 140801.0                      0       0      0        0         0
# 140901.0                      0       0      0        0         0
# 141001.0                      0       0      0        0         0
# 141901.0                      0       0      0        0         0
# 142701.0                      0       0      0        0         0
# 143601.0                      0       0      1        0         0
# 151501.0                      0       0      0        0         0
# 159999.0                      0       0      1        0         1
# 220201.0                      0       1      0        0         0
# 240102.0                      0       0      0        0         0
# 260101.0                      0       0      0        0         0
# 260202.0                      0       0      0        0         0
# 261501.0                      0       0      0        0         0
# 390602.0                      0       1      0        1         0
# 400501.0                      0       0      0        0         0
# 440701.0                      0       0      0        0         0
# 450601.0                      1       0      0        0         0
# 450604.0                      0       1      0        0         0
# 450701.0                      0       0      0        0         0
# 512207.0                      0       0      0        0         0
# 520201.0                      0       0      1        0         0
# 520205.0                      0       0      0        0         0
# 520301.0                      0       0      0        0         0
# 520801.0                      0       0      0        0         2
# 521302.0                      0       0      1        0         1
# 521304.0                      0       0      0        0         0
# 521401.0                      0       0      0        0         0
#
# Nation of Citizenship  Saudi Arabia  Spain  Taiwan, Republic of China  Turkey  \
# cip
# 90101.0                           2      0                          0       0
# 99999.0                           1      0                          0       0
# 110103.0                         12      0                          1       0
# 110401.0                          1      0                          0       0
# 110701.0                          2      0                          0       0
# 110802.0                          0      0                          1       0
# 130401.0                          7      0                          0       0
# 130406.0                          0      0                          0       0
# 131099.0                          1      0                          0       0
# 131202.0                          0      0                          1       0
# 131312.0                          0      0                          0       0
# 139999.0                          4      0                          0       0
# 140801.0                          0      0                          0       0
# 140901.0                          1      0                          0       0
# 141001.0                          8      0                          0       1
# 141901.0                         13      0                          0       0
# 142701.0                          2      0                          0       0
# 143601.0                          3      0                          0       0
# 151501.0                          8      0                          0       0
# 159999.0                          0      0                          0       0
# 220201.0                          0      2                          0       0
# 240102.0                          2      0                          2       0
# 260101.0                          0      0                          0       0
# 260202.0                          1      0                          0       0
# 261501.0                          1      0                          0       0
# 390602.0                          0      0                          0       0
# 400501.0                          0      0                          0       0
# 440701.0                          1      0                          0       0
# 450601.0                          0      0                          0       0
# 450604.0                          0      0                          0       0
# 450701.0                          0      0                          0       0
# 512207.0                          4      0                          0       0
# 520201.0                          0      0                          0       0
# 520205.0                          4      0                          0       0
# 520301.0                          2      0                          0       0
# 520801.0                          0      0                          0       0
# 521302.0                          0      1                          2       0
# 521304.0                          0      0                          0       0
# 521401.0                          2      0                          0       0
#
# Nation of Citizenship  United Kingdom  Viet Nam
# cip
# 90101.0                             0         0
# 99999.0                             0         0
# 110103.0                            0         3
# 110401.0                            0         0
# 110701.0                            0         0
# 110802.0                            0         3
# 130401.0                            0         1
# 130406.0                            0         1
# 131099.0                            0         0
# 131202.0                            0         0
# 131312.0                            0         0
# 139999.0                            0         0
# 140801.0                            0         1
# 140901.0                            0         1
# 141001.0                            1         1
# 141901.0                            0         2
# 142701.0                            0         0
# 143601.0                            0         0
# 151501.0                            0         0
# 159999.0                            0         0
# 220201.0                            0         0
# 240102.0                            0         0
# 260101.0                            0         2
# 260202.0                            0         2
# 261501.0                            0         0
# 390602.0                            0         0
# 400501.0                            0         1
# 440701.0                            0         0
# 450601.0                            0         0
# 450604.0                            0         0
# 450701.0                            1         0
# 512207.0                            0         0
# 520201.0                            0         1
# 520205.0                            0         0
# 520301.0                            0         1
# 520801.0                            0         1
# 521302.0                            0         2
# 521304.0                            0         1
# 521401.0                            0         2
